# %% [markdown]
#  # Chest X-Ray Classification with DenseNet121
#
#  ## Hyperparameter Tuning Notebook
#
# This notebook performs hyperparameter optimization for a DenseNet121 model on chest X-ray classification.

# %%
# !nvidia-smi
# Out:
# Wed Apr  2 13:02:56 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.144.03             Driver Version: 550.144.03     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       On  |   00000000:00:1E.0 Off |                    0 |
# | N/A   23C    P8             10W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Install Required Packages

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow>=2.6.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.17.0)
# Collecting keras_tuner>=1.1.0 (from -r requirements.txt (line 2))
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (3.10.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: pillow>=8.0.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: h5py>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (3.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (1.62.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.8.0)
# Collecting kt-legacy (from keras_tuner>=1.1.0->-r requirements.txt (line 2))
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 5)) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2025.1)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.6.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow>=2.6.0->-r requirements.txt (line 1)) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5

# %%
# !unzip balanced_dataset.zip -d ./balanced_dataset
# Out:
# Archive:  balanced_dataset.zip
#    creating: ./balanced_dataset/balanced_dataset/
#    creating: ./balanced_dataset/balanced_dataset/train/
#    creating: ./balanced_dataset/balanced_dataset/train/Atelectasis/
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00007922_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004822_025.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004915_006.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00028410_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00013373_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00016898_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00005348_006.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00002491_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00008191_006.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00021024_008.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00000381_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00019967_023.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00003851_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00026122_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00007317_012.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00030439_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00026925_008.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00005172_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00010780_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00018580_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00019643_019.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00020408_026.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00019049_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00006958_001.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00012293_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00025285_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00029464_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00019041_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00015255_006.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00011808_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00020945_005.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00019981_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00016285_001.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004668_001.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00028247_001.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004952_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00025527_011.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00000109_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00018541_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00022019_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00020960_001.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00003359_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004809_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00012471_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00019495_006.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00022815_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00017093_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00012905_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00018249_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00020147_008.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00008287_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004577_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00010830_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00005202_005.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00009729_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00028284_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004404_006.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00006941_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00012342_005.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00014688_007.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00011596_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00007023_005.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00022512_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00004959_009.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00016333_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00010384_008.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00003192_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00007317_011.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00021373_008.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00013384_006.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00010887_011.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00002598_001.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00016490_011.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00001984_012.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00015900_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00026298_001.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00003148_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00001088_022.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00018574_003.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00002599_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00001270_005.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00000431_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00011495_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00008894_000.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00027533_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00008922_021.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00006297_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00006022_007.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00020601_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00015843_014.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00010500_002.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00011868_005.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/00003787_004.png
#   inflating: ./balanced_dataset/balanced_dataset/train/Atelectasis/
I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 2. Directory Setup & Parameters

# %%
# !ls -l
# Out:
# total 575692
# -rw-r--r-- 1 sagemaker-user users      5091 Apr  2 13:01 balance_dataset.py
# drwxrwxr-x 5 sagemaker-user users        42 Mar 23 09:35 balanced_dataset
# -rw-r--r-- 1 sagemaker-user users 588914598 Apr  2 13:10 balanced_dataset.zip
# -rw-r--r-- 1 sagemaker-user users      1646 Apr  2 13:01 data_spliting.py
# -rw-r--r-- 1 sagemaker-user users      5394 Apr  2 13:01 densenet121.py
# -rw-r--r-- 1 sagemaker-user users      9000 Apr  2 13:01 hyperparameter_tuning.py
# -rw-r--r-- 1 sagemaker-user users    553272 Apr  2 13:11 hyperparameter_tunning.ipynb
# drwxr-xr-x 4 sagemaker-user users        52 Apr  2 13:01 logs_1
# -rw-r--r-- 1 sagemaker-user users       129 Apr  2 13:01 requirements.txt

# %%
# -----------------------------
# A) Directory Setup & Hyperparams
# -----------------------------
OUTPUT_DIR = './balanced_dataset'
CLASSES = ['Atelectasis', 'Cardiomegaly', 'No Finding', 'Nodule', 'Pneumothorax']

TRAIN_DIR = os.path.join(OUTPUT_DIR, 'train')
VAL_DIR   = os.path.join(OUTPUT_DIR, 'val')
TEST_DIR  = os.path.join(OUTPUT_DIR, 'test')

IMG_SIZE  = (512, 512)
NUM_CLASSES = len(CLASSES)

# %% [markdown]
# ## 3. Data Generators

# %%
# -----------------------------
# B) Data Generators
# -----------------------------
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    zoom_range=0.2,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    channel_shift_range=0.1,
    fill_mode='reflect',
    preprocessing_function=lambda x: tf.image.random_contrast(x, lower=0.8, upper=1.2)
)

val_datagen = ImageDataGenerator(rescale=1.0/255)

# %% [markdown]
# ## 4. Model Building Function for Keras Tuner

# %%
# -----------------------------
# C) Model Building Function for Keras Tuner
# -----------------------------
def build_model(hp):
    # Hyperparameters to tune
    l2_reg = hp.Float('l2_reg', min_value=1e-6, max_value=1e-2, sampling='log')
    dropout_rate = hp.Float('dropout_rate', min_value=0.1, max_value=0.7, step=0.1)
    dense_units_1 = hp.Int('dense_units_1', min_value=512, max_value=2048, step=256)
    dense_units_2 = hp.Int('dense_units_2', min_value=256, max_value=1024, step=256)
    dense_units_3 = hp.Int('dense_units_3', min_value=128, max_value=512, step=128)
    learning_rate = hp.Float('learning_rate', min_value=1e-5, max_value=1e-3, sampling='log')

    # Build the model
    base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    base_model.trainable = True

    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(dense_units_1, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_reg)),
        layers.BatchNormalization(),
        layers.Dropout(dropout_rate),
        layers.Dense(dense_units_2, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_reg)),
        layers.BatchNormalization(),
        layers.Dropout(dropout_rate),
        layers.Dense(dense_units_3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_reg)),
        layers.BatchNormalization(),
        layers.Dropout(dropout_rate),
        layers.Dense(NUM_CLASSES, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(l2_reg))
    ])

    # Compile the model
    model.compile(
        optimizer=optimizers.Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# ## 5. Tuner Setup

# %%
# -----------------------------
# D) Tuner Setup
# -----------------------------
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,  # Number of trials to run
    directory='hyperparameter_tuning',
    project_name='densenet121_tuning'
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743599576.788936    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.234188    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.237552    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.242341    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.245456    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.248404    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.502375    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.504553    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1743599577.506442    1622 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-02 13:12:57.508238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13764 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# ## 6. Callbacks Setup

# %%
# -----------------------------
# E) Callbacks
# -----------------------------
# Create a timestamp for unique log directory
timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = os.path.join('logs', timestamp)

# Enhanced TensorBoard callback with more metrics
tensorboard_cb = TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    update_freq='batch',
    write_graph=True,
    write_images=True,
    profile_batch=2
)

# Create checkpoints directory if it doesn't exist
os.makedirs('checkpoints', exist_ok=True)

# Callbacks for hyperparameter search (without checkpoint)
search_callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7),
    tensorboard_cb
]

# Callbacks for final training (with checkpoint)
final_callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7),
    tensorboard_cb,
    ModelCheckpoint(
        filepath=os.path.join('checkpoints', f'best_model_{timestamp}.h5'),
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
]
# Out:
# 2025-04-02 13:13:24.004750: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:103] Profiler session initializing.
# 2025-04-02 13:13:24.004784: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:118] Profiler session started.
# 2025-04-02 13:13:24.006662: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:892] Profiler found 1 GPUs
# 2025-04-02 13:13:24.079139: W external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:999] Fail to use per-thread activity buffer, cupti trace overhead may be big. CUPTI ERROR CODE:1
# 2025-04-02 13:13:24.079366: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:130] Profiler session tear down.
# 2025-04-02 13:13:24.079499: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1036] CUPTI activity buffer flushed

# %% [markdown]
# ## 7. Run Hyperparameter Search

# %%
# -----------------------------
# F) Run Hyperparameter Search
# -----------------------------
print(f"\nStarting hyperparameter search. TensorBoard logs will be saved to: {log_dir}")
print(f"To view TensorBoard, run: tensorboard --logdir {log_dir}")
tuner.search(
    train_datagen.flow_from_directory(
        directory=TRAIN_DIR,
        target_size=IMG_SIZE,
        batch_size=8,  # Fixed batch size
        class_mode='categorical'
    ),
    validation_data=val_datagen.flow_from_directory(
        directory=VAL_DIR,
        target_size=IMG_SIZE,
        batch_size=8,  # Fixed batch size
        class_mode='categorical'
    ),
    callbacks=search_callbacks,  # Use search callbacks without checkpoint
    epochs=100  # Fixed epochs
)
# Out:
# Starting hyperparameter search. TensorBoard logs will be saved to: logs/20250402-131324
# To view TensorBoard, run: tensorboard --logdir logs/20250402-131324
# Found 4370 images belonging to 5 classes.
# Found 545 images belonging to 5 classes.
#
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 2.7335e-05        |2.7335e-05        |l2_reg
# 0.2               |0.2               |dropout_rate
# 2048              |2048              |dense_units_1
# 256               |256               |dense_units_2
# 384               |384               |dense_units_3
# 0.00097217        |0.00097217        |learning_rate
# /opt/conda/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# I0000 00:00:1743599676.854692    6446 service.cc:146] XLA service 0x7f9c300591c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743599676.854729    6446 service.cc:154]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2025-04-02 13:14:38.858259: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-02 13:14:45.664170: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90701
# 2025-04-02 13:17:36.619231: E external/local_xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module a_inference_one_step_on_data_87794__.56235] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2025-04-02 13:17:39.642571: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_2', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_3', 12 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion', 20 bytes spill stores, 24 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_21', 24 bytes spill stores, 28 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_reduce_window_fusion_1', 276 bytes spill stores, 272 bytes spill loads
#
# 2025-04-02 13:17:40.301046: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2m3.681880478s
#
# ********************************
# [Compiling module a_inference_one_step_on_data_87794__.56235] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# I0000 00:00:1743599860.311016    6446 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   1/547 ━━━━━━━━━━━━━━━━━━━━ 36:46:17 242s/step - accuracy: 0.2500 - loss: 3.0178
# 2025-04-02 13:17:40.835958: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:103] Profiler session initializing.
# 2025-04-02 13:17:40.835996: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:118] Profiler session started.
# 2025-04-02 13:17:40.867677: W external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:999] Fail to use per-thread activity buffer, cupti trace overhead may be big. CUPTI ERROR CODE:1
# 2025-04-02 13:17:41.194127: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:68] Profiler session collecting data.
# 2025-04-02 13:17:41.353274: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1036] CUPTI activity buffer flushed
#   2/547 ━━━━━━━━━━━━━━━━━━━━ 6:34 724ms/step - accuracy: 0.2812 - loss: 2.7723
# 2025-04-02 13:17:41.498279: I external/local_xla/xla/backends/profiler/gpu/cupti_collector.cc:534]  GpuTracer has collected 2542 callback api events and 3085 activity events.
# 2025-04-02 13:17:41.526043: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:130] Profiler session tear down.
# 2025-04-02 13:17:41.532998: I external/local_tsl/tsl/profiler/rpc/client/save_profile.cc:147] Collecting XSpace to repository: logs/20250402-131324/00/execution0/train/plugins/profile/2025_04_02_13_17_41/default.xplane.pb
#  11/547 ━━━━━━━━━━━━━━━━━━━━ 6:45 756ms/step - accuracy: 0.2944 - loss: 2.5485

# %% [markdown]
# ## 8. Get Best Hyperparameters

# %%
# -----------------------------
# G) Get Best Hyperparameters
# -----------------------------
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("\nBest Hyperparameters:")
print(f"L2 Regularization: {best_hps.get('l2_reg')}")
print(f"Dropout Rate: {best_hps.get('dropout_rate')}")
print(f"Dense Units 1: {best_hps.get('dense_units_1')}")
print(f"Dense Units 2: {best_hps.get('dense_units_2')}")
print(f"Dense Units 3: {best_hps.get('dense_units_3')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")

# %% [markdown]
# ## 9. Train Final Model with Best Hyperparameters

# %%
print("\nTraining final model with best hyperparameters...")
model = tuner.hypermodel.build(best_hps)
history = model.fit(
    train_datagen.flow_from_directory(
        directory=TRAIN_DIR,
        target_size=IMG_SIZE,
        batch_size=8,  # Fixed batch size
        class_mode='categorical'
    ),
    validation_data=val_datagen.flow_from_directory(
        directory=VAL_DIR,
        target_size=IMG_SIZE,
        batch_size=8,  # Fixed batch size
        class_mode='categorical'
    ),
    epochs=50,  # Fixed epochs
    callbacks=final_callbacks  # Use final callbacks with checkpoint
)

# Save the best model
model.save('best_model_tuned.h5')
print(f"\nTraining complete! Model saved as 'best_model_tuned.h5'")
print(f"To view training metrics in TensorBoard, run: tensorboard --logdir logs")

# %% [markdown]
# ## 10. Plot Training History

# %%
plt.figure(figsize=(16, 6))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.savefig('training_history.png')
plt.show()

# %% [markdown]
# ## 11. Evaluate on Test Set and Plot Confusion Matrix

# %%
# -----------------------------
# I) Evaluate on Test Set and Plot Confusion Matrix
# -----------------------------
print("\nEvaluating model on test set...")
test_datagen = ImageDataGenerator(rescale=1.0/255)
test_generator = test_datagen.flow_from_directory(
    directory=TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=8,  # Fixed batch size
    class_mode='categorical',
    shuffle=False
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# Get predictions
predictions = model.predict(test_generator, steps=test_generator.samples // test_generator.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Compute and plot confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Best Model")
plt.tight_layout()
plt.savefig('confusion_matrix_best_model.png')
plt.close()

# Print classification report
from sklearn.metrics import classification_report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
